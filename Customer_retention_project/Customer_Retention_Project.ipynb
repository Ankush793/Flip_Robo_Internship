# %% [markdown]
# # Customer_Retention_Project

# %%
import pandas as pd                                   #importing required libraries
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

# %%
df=pd.read_csv("customer_retention.csv")                #loading dataset
df
# Out:
#     1Gender of respondent 2 How old are you?   \
# 0                    Male         31-40 years
# 1                  Female         21-30 years
# 2                  Female         21-30 years
# 3                    Male         21-30 years
# 4                  Female         21-30 years
# ..                    ...                 ...
# 264                Female         21-30 years
# 265                Female         31-40 years
# 266                Female         41-50 yaers
# 267                Female  Less than 20 years
# 268                Female         41-50 yaers
#
#     3 Which city do you shop online from?  \
# 0                                   Delhi
# 1                                   Delhi
# 2                           Greater Noida
# 3                                 Karnal
# 4                              Bangalore
# ..                                    ...
# 264                                 Solan
# 265                             Ghaziabad
# ...

# %%
df=pd.DataFrame(data=df)
df                            #giving structural format to dataset
# Out:
#     1Gender of respondent 2 How old are you?   \
# 0                    Male         31-40 years
# 1                  Female         21-30 years
# 2                  Female         21-30 years
# 3                    Male         21-30 years
# 4                  Female         21-30 years
# ..                    ...                 ...
# 264                Female         21-30 years
# 265                Female         31-40 years
# 266                Female         41-50 yaers
# 267                Female  Less than 20 years
# 268                Female         41-50 yaers
#
#     3 Which city do you shop online from?  \
# 0                                   Delhi
# 1                                   Delhi
# 2                           Greater Noida
# 3                                 Karnal
# 4                              Bangalore
# ..                                    ...
# 264                                 Solan
# 265                             Ghaziabad
# ...

# %% [markdown]
# # EDA(EXPLORATORY DATA ANALYSIS):

# %%
df.head(5)
# Out:
#   1Gender of respondent 2 How old are you?   \
# 0                  Male         31-40 years
# 1                Female         21-30 years
# 2                Female         21-30 years
# 3                  Male         21-30 years
# 4                Female         21-30 years
#
#   3 Which city do you shop online from?  \
# 0                                 Delhi
# 1                                 Delhi
# 2                         Greater Noida
# 3                               Karnal
# 4                            Bangalore
#
#    4 What is the Pin Code of where you shop online from?  \
# 0                                             110009
# 1                                             110030
# 2                                             201308
# 3                                             132001
# 4                                             530068
#
#   5 Since How Long You are Shopping Online ?  \
# 0                              Above 4 years
# ...

# %%
df.tail()
# Out:
#     1Gender of respondent 2 How old are you?   \
# 264                Female         21-30 years
# 265                Female         31-40 years
# 266                Female         41-50 yaers
# 267                Female  Less than 20 years
# 268                Female         41-50 yaers
#
#     3 Which city do you shop online from?  \
# 264                                 Solan
# 265                             Ghaziabad
# 266                            Bangalore
# 267                                 Solan
# 268                             Ghaziabad
#
#      4 What is the Pin Code of where you shop online from?  \
# 264                                             173212
# 265                                             201008
# 266                                             560010
# 267                                             173229
# 268                                             201009
#
#     5 Since How Long You are Shopping Online ?  \
# ...

# %%
df.shape
# Out:
# (269, 71)

# %% [markdown]
# The mark of this issue is to effectively research the diffrerent factors affecting client retenstion and incitation in e-commerece retail.
#
#
# The dataset has information concerning these features, it moreover gives a comprehension of the recommended locales.
#
#
# Different variables concerning costomer age, direction, city, etc close by the effortlessness of working of destinations is referred to in this dataset. In like manner, the effect of design,navigation, organizations, offers, etc of the site on the client for thier shopping needs is accessible.

# %%
df.columns
# Out:
# Index(['1Gender of respondent', '2 How old are you? ',
#        '3 Which city do you shop online from?',
#        '4 What is the Pin Code of where you shop online from?',
#        '5 Since How Long You are Shopping Online ?',
#        '6 How many times you have made an online purchase in the past 1 year?',
#        '7 How do you access the internet while shopping on-line?',
#        '8 Which device do you use to access the online shopping?',
#        '9 What is the screen size of your mobile device?\t\t\t\t\t\t                                        ',
#        '10 What is the operating system (OS) of your device?\t\t\t\t                                          ',
#        '11 What browser do you run on your device to access the website?\t\t\t                                                          ',
#        '12 Which channel did you follow to arrive at your favorite online store for the first time?                                                                   ',
# ...

# %%
df.dtypes
# Out:
# 1Gender of respondent                                                   object
# 2 How old are you?                                                      object
# 3 Which city do you shop online from?                                   object
# 4 What is the Pin Code of where you shop online from?                    int64
# 5 Since How Long You are Shopping Online ?                              object
#                                                                          ...
# Longer delivery period                                                  object
# Change in website/Application design                                    object
# Frequent disruption when moving from one page to another                object
# Website is as efficient as before                                       object
# Which of the Indian online retailer would you recommend to a friend?    object
# Length: 71, dtype: object

# %% [markdown]
# # Converting the data type of pincode from integer to Object

# %%
df["4 What is the Pin Code of where you shop online from?"]=df["4 What is the Pin Code of where you shop online from?"].astype(object)

# %%
df.dtypes               #now we can see that pincode column is changed to object datatype
# Out:
# 1Gender of respondent                                                   object
# 2 How old are you?                                                      object
# 3 Which city do you shop online from?                                   object
# 4 What is the Pin Code of where you shop online from?                   object
# 5 Since How Long You are Shopping Online ?                              object
#                                                                          ...
# Longer delivery period                                                  object
# Change in website/Application design                                    object
# Frequent disruption when moving from one page to another                object
# Website is as efficient as before                                       object
# Which of the Indian online retailer would you recommend to a friend?    object
# Length: 71, dtype: object

# %%
#We can not see all the columns. so, we need to use pd.set_option to display both columns and rows in maximum 

pd.set_option('display.max_columns',None)
pd.set_option('display.max_rows',None)

# %%
df.dtypes
# Out:
# 1Gender of respondent                                                                                                                                                                                                  object
# 2 How old are you?                                                                                                                                                                                                     object
# 3 Which city do you shop online from?                                                                                                                                                                                  object
# 4 What is the Pin Code of where you shop online from?                                                                                                                                                                  object
# ...

# %% [markdown]
# 1. from above we can see all the columns and their data types.
#
# 2. all the columns consist of objective data types except column no.4-what is the pin code of where you shop online from?

# %% [markdown]
# # Null values:

# %%
df.isnull().sum()
# Out:
# 1Gender of respondent                                                                                                                                                                                                  0
# 2 How old are you?                                                                                                                                                                                                     0
# 3 Which city do you shop online from?                                                                                                                                                                                  0
# 4 What is the Pin Code of where you shop online from?                                                                                                                                                                  0
# ...

# %%
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %% [markdown]
# There is no null value in any of the column in our dataset

# %%
# checking the different categories of features and the presence of missing values
df_statistic = pd.DataFrame(columns = ['column', 'values','unique_values','unique_values_without_nan','null_miss','pct_miss'])
ds = pd.DataFrame()

for c in df.columns:
    ds['column'] =[c]
    ds['values'] = [df[c].unique()]
    ds['unique_values'] = len(list(df[c].unique()))
    ds['unique_values_without_nan'] = int(df[c].nunique())
    ds['null_values'] = df[c].isnull().sum()
    ds['pct_miss'] = (df[c].isnull().sum()/len(df)).round(3)*100
    df_statistic = df_statistic.append(ds)
df_statistic
# Out:
#                                               column  \
# 0                              1Gender of respondent
# 0                                2 How old are you?
# 0              3 Which city do you shop online from?
# 0  4 What is the Pin Code of where you shop onlin...
# 0         5 Since How Long You are Shopping Online ?
# 0  6 How many times you have made an online purch...
# 0  7 How do you access the internet while shoppin...
# 0  8 Which device do you use to access the online...
# 0  9 What is the screen size of your mobile devic...
# 0  10 What is the operating system (OS) of your d...
# 0  11 What browser do you run on your device to a...
# 0  12 Which channel did you follow to arrive at y...
# 0  13 After first visit, how do you reach the onl...
# 0  14 How much time do you explore the e- retail ...
# 0  15 What is your preferred payment Option?\t\t\...
# 0  16 How frequently do you abandon (selecting an...
# 0  17 Why did you abandon the �Bag�, �Shopping Ca...
# ...

# %% [markdown]
# We can see the various classifications in each column. For instance, there are 5 age classes every one of the 11 unique cities of the customers. 11 unique cities range, of 39 pincodes.
#
# Despite the fact that there are five retailers referenced in this dataframe, there are numerous qualities in cells which bring about expansion in the quantity of classes. Numerous clients demonstrate that various sites have a specific element. For instance, in longer page showing time both myntra and snapdeal are referenced in a solitary cell.
#
# The null_miss and the pct_miss obviously demonstrating that the dataset has no missing qualities.

# %%
sns.countplot(df["1Gender of respondent"])
# Out:
# <AxesSubplot:xlabel='1Gender of respondent', ylabel='count'>

# %% [markdown]
# As we can see that there are mostly females present in the Dataset and Males are around half of females

# %%
plt.figure(figsize=(8,5))
sns.countplot(df["2 How old are you? "])
# Out:
# <AxesSubplot:xlabel='2 How old are you? ', ylabel='count'>

# %% [markdown]
# as we can see, almost equal numbers of customers are in age group of 21-30 years and 31-40 years, which is high as
# compare to other groups

# %%
plt.figure(figsize=(10,5))
sns.countplot(df["3 Which city do you shop online from?"])
# Out:
# <AxesSubplot:xlabel='3 Which city do you shop online from?', ylabel='count'>

# %% [markdown]
# Most of the customers shop from the Delhi and Noida Cities. Noida includes Noida and Greater Noida

# %%
df["4 What is the Pin Code of where you shop online from?"].value_counts()
# Out:
# 201308    38
# 132001    19
# 201310    18
# 110044    16
# 173229     9
# 250001     9
# 173212     9
# 560010     8
# 132036     8
# 560037     8
# 122018     8
# 110011     7
# 201306     7
# 110008     7
# 110018     6
# 110014     6
# 244001     5
# 201312     5
# 201009     5
# 530068     5
# 201305     5
# 201008     5
# 201304     4
# 122009     4
# 110030     4
# 201303     4
# 560018     4
# 560002     4
# 201005     4
# 201001     4
# 110039     4
# 110009     4
# 110042     4
# 560003     4
# 560013     3
# 203001     2
# 203202     1
# 203207     1
# 560001     1
# Name: 4 What is the Pin Code of where you shop online from?, dtype: int64

# %%
plt.figure(figsize=(30,12))
sns.countplot(df["4 What is the Pin Code of where you shop online from?"])
# Out:
# <AxesSubplot:xlabel='4 What is the Pin Code of where you shop online from?', ylabel='count'>

# %% [markdown]
# As we can see that most Customers are from pin code 201308 while least are from pincode 560001,203207 and 203202

# %%
plt.figure(figsize=(10,5))
sns.countplot(df["5 Since How Long You are Shopping Online ?"])
# Out:
# <AxesSubplot:xlabel='5 Since How Long You are Shopping Online ?', ylabel='count'>

# %% [markdown]
# Most customers are shopping online for more than 4 years and very few new customers are in the segment of 2 years and less.

# %%
plt.figure(figsize=(10,5))
sns.countplot(df["6 How many times you have made an online purchase in the past 1 year?"])
# Out:
# <AxesSubplot:xlabel='6 How many times you have made an online purchase in the past 1 year?', ylabel='count'>

# %% [markdown]
# Most customers have purchased less than 10 times in past 1 year whereas very less customers have purchased more than 40 times
#
# Some good amount of customers also purchased between 31-40 times in the past 1 year

# %%
plt.figure(figsize=(10,5))
sns.countplot(df["7 How do you access the internet while shopping on-line?"])
# Out:
# <AxesSubplot:xlabel='7 How do you access the internet while shopping on-line?', ylabel='count'>

# %% [markdown]
# More than half of the customers use Mobile data internet while making an online purchase

# %%
plt.figure(figsize=(10,5))
sns.countplot(df["8 Which device do you use to access the online shopping?"])
# Out:
# <AxesSubplot:xlabel='8 Which device do you use to access the online shopping?', ylabel='count'>

# %% [markdown]
# Mostly Smartphones and laptops are used to access the online shopping

# %%
plt.figure(figsize=(10,5))
sns.countplot(df["9 What is the screen size of your mobile device?\t\t\t\t\t\t                                        "])
# Out:
# <AxesSubplot:xlabel='9 What is the screen size of your mobile device?\t\t\t\t\t\t                                        ', ylabel='count'>

# %% [markdown]
# Most people use the mobile screen which has above 5.5 inches screen size

# %%
plt.figure(figsize=(10,5))
sns.countplot(df["10 What is the operating system (OS) of your device?\t\t\t\t                                          "])
# Out:
# <AxesSubplot:xlabel='10 What is the operating system (OS) of your device?\t\t\t\t                                          ', ylabel='count'>

# %% [markdown]
# Most people have devices that have Windows and Android OS, while very few IOS users are there

# %%
plt.figure(figsize=(10,5))
sns.countplot(df["11 What browser do you run on your device to access the website?\t\t\t                                                          "])
# Out:
# <AxesSubplot:xlabel='11 What browser do you run on your device to access the website?\t\t\t                                                          ', ylabel='count'>

# %% [markdown]
# Google Chrome is the most used browser to access online shopping, almost all customers use Google Chrome as their browser

# %%
plt.figure(figsize=(10,5))
sns.countplot(df["14 How much time do you explore the e- retail store before making a purchase decision?                                                                   "])
# Out:
# <AxesSubplot:xlabel='14 How much time do you explore the e- retail store before making a purchase decision?                                                                   ', ylabel='count'>

# %% [markdown]
# Before making a purchase, more number of customers spend more than 15 min which indicated that these significant numbers of people compare items in terms of quality and cost before buying an item.
#
# Very very less customers spend less than 5 mins and buy items without much researching

# %%
plt.figure(figsize=(10,5))
sns.countplot(df["15 What is your preferred payment Option?\t\t\t\t\t                                                                                                                               "])
# Out:
# <AxesSubplot:xlabel='15 What is your preferred payment Option?\t\t\t\t\t                                                                                                                               ', ylabel='count'>

# %% [markdown]
# This graph shows that most customers use card payment method as it is easy and quick, very few customers use e-wallet
#
# Few customers use Cash on Delivery option as it is a time taking process

# %%
plt.figure(figsize=(10,5))
sns.countplot(df["16 How frequently do you abandon (selecting an items and leaving without making payment) your shopping cart?\t\t\t\t\t\t\t                                                   "])
# Out:
# <AxesSubplot:xlabel='16 How frequently do you abandon (selecting an items and leaving without making payment) your shopping cart?\t\t\t\t\t\t\t                                                   ', ylabel='count'>

# %% [markdown]
# This graph shows that most customers abandon a payment cart without making payment only sometimes.
#
# Very few customers do it frequently and very frequently which can be termed as time pass or window shopping customers

# %%
plt.figure(figsize=(10,5))
sns.countplot(df["18 The content on the website must be easy to read and understand"])
# Out:
# <AxesSubplot:xlabel='18 The content on the website must be easy to read and understand', ylabel='count'>

# %% [markdown]
# Most customers find easy in understanding what they are buying and the website is easy to read and use while it does not require much time to operate
#
# Very very few customers like complex content and language used

# %%
plt.figure(figsize=(10,5))
sns.countplot(df["19 Information on similar product to the one highlighted  is important for product comparison"])
# Out:
# <AxesSubplot:xlabel='19 Information on similar product to the one highlighted  is important for product comparison', ylabel='count'>

# %% [markdown]
# Most customers agree that for product comparison there must be proper information of similar products as well

# %%
plt.figure(figsize=(10,5))
sns.countplot(df["20 Complete information on listed seller and product being offered is important for purchase decision."])
# Out:
# <AxesSubplot:xlabel='20 Complete information on listed seller and product being offered is important for purchase decision.', ylabel='count'>

# %% [markdown]
# Almost all customers have a viewpoint that it is very important to have details of the product and seller to make a purchase decision
#
# Therefore if a product or seller is not well detailed then most chances are that it will not increase the sales

# %%
plt.figure(figsize=(10,5))
sns.countplot(df["21 All relevant information on listed products must be stated clearly"])
# Out:
# <AxesSubplot:xlabel='21 All relevant information on listed products must be stated clearly', ylabel='count'>

# %% [markdown]
# All customers agree that the products must contain all the relevant information and nothing must be concealed

# %%
plt.figure(figsize=(15,5))
sns.countplot(df["22 Ease of navigation in website"])
# Out:
# <AxesSubplot:xlabel='22 Ease of navigation in website', ylabel='count'>

# %% [markdown]
# most customers thinks that, the website must be easy to understand and easy to navigate

# %%
plt.figure(figsize=(15,5))
sns.countplot(df["23 Loading and processing speed"])
# Out:
# <AxesSubplot:xlabel='23 Loading and processing speed', ylabel='count'>

# %% [markdown]
# This graph shows that customers dont like to wait much when it comes to website page loading and payment processing

# %%
plt.figure(figsize=(15,5))
sns.countplot(df["25 Convenient Payment methods"])
# Out:
# <AxesSubplot:xlabel='25 Convenient Payment methods', ylabel='count'>

# %% [markdown]
# Almost all customers strongly agree that the payment methods must be convenient

# %%
plt.figure(figsize=(15,5))
sns.countplot(df["26 Trust that the online retail store will fulfill its part of the transaction at the stipulated time"])
# Out:
# <AxesSubplot:xlabel='26 Trust that the online retail store will fulfill its part of the transaction at the stipulated time', ylabel='count'>

# %% [markdown]
# It is very important factor for the customer to revisit the site that the transaction or purchase must be made within the specified time

# %%
plt.figure(figsize=(15,5))
sns.countplot(df["28 Being able to guarantee the privacy of the customer"])
# Out:
# <AxesSubplot:xlabel='28 Being able to guarantee the privacy of the customer', ylabel='count'>

# %% [markdown]
# All customers want their privacy to be secure and safe, customers prefer secured and safe sites for regular purchases

# %%
plt.figure(figsize=(15,5))
sns.countplot(df["30 Online shopping gives monetary benefit and discounts"])
# Out:
# <AxesSubplot:xlabel='30 Online shopping gives monetary benefit and discounts', ylabel='count'>

# %% [markdown]
# Most customers are of positive view of buying the products online if offered good discounts and monetary benefits

# %%
plt.figure(figsize=(15,5))
sns.countplot(df["33 Return and replacement policy of the e-tailer is important for purchase decision"])
# Out:
# <AxesSubplot:xlabel='33 Return and replacement policy of the e-tailer is important for purchase decision', ylabel='count'>

# %% [markdown]
# As can be seen from graph almost all customers want return and replacement policy
#
#
# The product which has return and replacement policy will sell much as compared to product without it

# %%
plt.figure(figsize=(15,5))
sns.countplot(df["35 Displaying quality Information on the website improves satisfaction of customers"])
# Out:
# <AxesSubplot:xlabel='35 Displaying quality Information on the website improves satisfaction of customers', ylabel='count'>

# %% [markdown]
# The customers are of viewpoint that the quality information and content on website will likely to increase the sales

# %%
plt.figure(figsize=(15,5))
sns.countplot(df["38 User satisfaction cannot exist without trust"])
# Out:
# <AxesSubplot:xlabel='38 User satisfaction cannot exist without trust', ylabel='count'>

# %% [markdown]
# Almost all customers strongly believe that there cannot be a user satisfaction without trust and trust is most important for increase in sales

# %%
plt.figure(figsize=(15,5))
sns.countplot(df["39 Offering a wide variety of listed product in several category"])
# Out:
# <AxesSubplot:xlabel='39 Offering a wide variety of listed product in several category', ylabel='count'>

# %% [markdown]
# most customers beleive that getting a chance to explore many product at one place can directly increase chance of higher sales

# %%
plt.figure(figsize=(15,5))
sns.countplot(df["43 Shopping on the website gives you the sense of adventure"])
# Out:
# <AxesSubplot:xlabel='43 Shopping on the website gives you the sense of adventure', ylabel='count'>

# %% [markdown]
# many customers believe that shopping online is adventerous, also many others not

# %%
plt.figure(figsize=(15,5))
sns.countplot(df["45 You feel gratification shopping on your favorite e-tailer"])
# Out:
# <AxesSubplot:xlabel='45 You feel gratification shopping on your favorite e-tailer', ylabel='count'>

# %% [markdown]
# Mainly the customers have mixed view on this, some believe that its satisfactory to shop on your favourite e-tailer while others dont believe as such

# %%
plt.figure(figsize=(15,5))
sns.countplot(df["46 Shopping on the website helps you fulfill certain roles"])
# Out:
# <AxesSubplot:xlabel='46 Shopping on the website helps you fulfill certain roles', ylabel='count'>

# %% [markdown]
# Some customers believe that it is helpful to shop online so it helps in certain roles while others dont view the same

# %%
plt.figure(figsize=(15,5))
sns.countplot(df["47 Getting value for money spent"])
# Out:
# <AxesSubplot:xlabel='47 Getting value for money spent', ylabel='count'>

# %% [markdown]
# Almost all customers strongly believe that getting value for money is a very big factor in buying a product from online website

# %%
plt.figure(figsize=(25,12))
sns.countplot(df["Which of the Indian online retailer would you recommend to a friend?"])
# Out:
# <AxesSubplot:xlabel='Which of the Indian online retailer would you recommend to a friend?', ylabel='count'>

# %% [markdown]
# As can be seen Amazon.in and Flipkart.com are the 2 most trusted and opted websites for online shopping among the customers

# %% [markdown]
# # Feature engineering:

# %%
df["3 Which city do you shop online from?"].replace(to_replace="Greater Noida", value="Noida",inplace=True)

#Replacing the Greater Noida location to Noida as both are same so no need to write and plot them separately

# %%
plt.figure(figsize=(15,5))
sns.countplot(df["3 Which city do you shop online from?"])
# Out:
# <AxesSubplot:xlabel='3 Which city do you shop online from?', ylabel='count'>

# %% [markdown]
# Now we can see that most customers shop online from Noida region and then Delhi comes after at 2nd spot

# %%
# Here we analyse why amazon is the most recommended retailer
# We also try to analyse factors come out to be the strongest in regards to recommendation and retention.
for i in [48,51,54,56,59,60]:
    df.columns[i]
    data = df.iloc[:,i].value_counts()
    labels = data.keys()
    plt.pie(data, autopct="%.1f%%",labels=labels)
    plt.title(df.columns[i])
    plt.show()

# %% [markdown]
# As you can see, customers appreciate the complete product information. It helps them make purchase decisions and builds trust in retailers. Over 35% believe that Amazon provides relevant explanations for products that contribute to the reasons most recommended. There are also factors that help retailers win the top spot, such as speed of delivery, speed of purchase, and great web applications. Customer revitalization can be achieved through offers and discounts, but service is paramount to maintaining customer interest as well as financial gain. The presence of online help that is sympathetic to the above factors fosters a beneficial addiction.
#
# As a global retailer, Amazon is also a leader in reliability. From the count plot, we found that trust is one of the most important things customers consider necessary to shop online. So it's not surprising that Amazon is the most recommended retailer.
# From all graph analysis, it is clear that the factors that consumers consider important play an important role in the recommended website. More referrals are  directly proportional to the number of customer activations and retentions. These factors are related to the value of both utility and pleasure.

# %% [markdown]
# # Label Encoder:

# %%
from sklearn.preprocessing import LabelEncoder             #Importing the Label Encoder from sklearn Library

# %%
le=LabelEncoder()

for i in df.columns:
    if df[i].dtypes=="object":
        df[i]=le.fit_transform(df[i].values.reshape(-1,1))

# %% [markdown]
# Running for loop to give numeric values to strings using the Label Encoder in training data

# %%
df
# Out:
#      1Gender of respondent  2 How old are you?   \
# 0                        1                    1
# 1                        0                    0
# 2                        0                    0
# 3                        1                    0
# 4                        0                    0
# 5                        0                    1
# 6                        1                    2
# 7                        1                    2
# 8                        0                    4
# 9                        0                    1
# 10                       1                    1
# 11                       0                    2
# 12                       0                    3
# 13                       0                    1
# 14                       0                    0
# 15                       0                    0
# 16                       1                    1
# 17                       1                    2
# ...

# %% [markdown]
# from above we can see that, all the string data types are converted into integer values
